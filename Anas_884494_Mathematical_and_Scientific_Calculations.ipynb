# %% [markdown]
# ## (1) Area of a Rectangle:

# %%
length=12
width=4
area=length*width
print("The area of rectangle is",(area))
# Out:
# The area of rectangle is 48

# %% [markdown]
# ## (2) Circumference of a Circle:

# %%
r=7
pi=3.14
Circumference=2*pi*r
print("Circumference of the circle is",(Circumference))
# Out:
# Circumference of the circle is 43.96

# %% [markdown]
# ## (3) Simple Interest:

# %%
p=50
r=20
t=10
Simple_Interest=(p*r*t)
print("The Simple_Interest is",(Simple_Interest))
# Out:
# The Simple_Interest is 10000

# %% [markdown]
# ## (4) Speed of an Object:

# %%
distance=100
time=2
speed=distance/time
print("The speed of the object is",(speed))
# Out:
# The speed of the object is 50.0

# %% [markdown]
# ## (5) BMI Calculator:

# %%
weight=70
height=1.75
bmi=weight/(height**2)
print("The BMI is",round(bmi,2))
# Out:
# The BMI is 22.86

# %% [markdown]
# ## (6) Force Using Newton's Second Law:

# %%
m=10
a=15
F=m*a
print("The Force of an object is",(F))
# Out:
# The Force of an object is 150

# %% [markdown]
# ## (7) Compound Interest:

# %%
p=1000
r=0.05
n=12
t=3
A=p*(1+r/n)**(n*t)
print("The Total amount of (A) is:",round(A,2))
# Out:
# The Total amount of (A) is: 1161.47

# %% [markdown]
# ## (8) Perimeter of a Triangle:

# %%
a=10
b=15
c=20
Perimeter=(a+b+c)
print("The Perimeter of a triangle is",(Perimeter))
# Out:
# The Perimeter of a triangle is 45

# %% [markdown]
# ## (9) Volume of a Sphere:

# %%
r=10
pi=3.14
Volume=(4/3)*pi*(r**3)
print(" The Volume of a sphere is",round(Volume,2))
# Out:
#  The Volume of a sphere is 4186.67

# %% [markdown]
# ## 10) Kinetic Energy:

# %%
m=20
v=10
KE=(1/2)*m*(v**2)
print("The kinetic energy of an object",(KE))
# Out:
# The kinetic energy of an object 1000.0

# %% [markdown]
# ## 11) Quadratic Equation Roots:

# %%
import math
a = 1
b = 5
c = 6
discriminant = (b ** 2) - (4 * a * c)
root1=(-b + math.sqrt(discriminant)) / (2 * a)
root2=(-b - math.sqrt(discriminant)) / (2 * a)
print("The first root (X1) is:",root1)
print("The second root (X2) is:",root2)
# Out:
# The first root (X1) is: -2.0
# The second root (X2) is: -3.0

# %% [markdown]
# ## 12) Temperature Conversion:

# %%
c=50.5
F=(9/5)* c+32
print(" The Fahrenheit is",F)
# Out:
#  The Fahrenheit is 122.9

# %% [markdown]
# ## 13) Gravitational Force:

# %%
m1=10
m2=20
r=30
g=6.67e-11
F=g*(m1*m2) / (r**2)
print(" The Gravitational force between two objects is",(F))
# Out:
#  The Gravitational force between two objects is 1.4822222222222224e-11

# %% [markdown]
# ## 14) Volume of a Cylinder:

# %%
r=20
h=30
pi=3.14
Volume= pi*(r**2)*h
print(" The volume of a cylinder is",(Volume))
# Out:
#  The volume of a cylinder is 37680.0

# %% [markdown]
# ## 15) Pressure:

# %%
f=20
a=30
P= f/a
print("The pressure is",(P))
# Out:
# The pressure is 0.6666666666666666

# %% [markdown]
# ## 16) Electric Power:

# %%
v=1000
i=500
P= v/i
print("The Power is",(P))
# Out:
# The Power is 2.0

# %% [markdown]
# ## 17) Perimeter of a Circle (Circumference):

# %%
r=20
pi=3.14
P=2*pi*r
print(" The perimeter (circumference) of a circle is",round(P,2))
# Out:
#  The perimeter (circumference) of a circle is 125.6

# %% [markdown]
# ## 18) Future Value in Savings:

# %%
pv=2000
r=0.055
t=3
FV= pv*(1+r)**t
print(" The future value of an investment is",round(FV,2))
# Out:
#  The future value of an investment is 2348.48

# %% [markdown]
# ## 19) Work Done by a Force:

# %%
import math

f=20
d=10
theta=60
theta_radians= math.radians(theta)
W=f*d*math.cos(math.radians(theta))
print("The work done by a force",round(W,3))
# Out:
# The work done by a force 100.0

# %% [markdown]
# ## 20) Heat Transfer:

# %%
m=20
c=4184
delta_T=10
Q=m*c*delta_T
print(" The amount of heat transferred is",(Q))
# Out:
#  The amount of heat transferred is 836800
